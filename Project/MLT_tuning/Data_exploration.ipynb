# %%
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
path = '/Users/HP Spectre/OneDrive - student.kit.edu/uni/Master/Lissabon Kurse/Intelligent Systems/IntSysGroup6/'

data = pd.read_csv(path+'Project/data/robot_inverse_kinematics_dataset.csv')

# %%
x = data.iloc[:,6:]
q = data.iloc[:,0:6]
x_numpy = x.to_numpy()
q_numpy = q.to_numpy()

# %%
for i in range(6):
    print(q_numpy[:,i].shape)
# Out:
# (15000,)
# (15000,)
# (15000,)
# (15000,)
# (15000,)
# (15000,)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=q_numpy)
plt.title("Boxplot of Joint Angels")
plt.show()

# %%
max_rad = q.max(axis=0)
max_deg = [math.degrees(angle) for angle in max_rad]
print(np.transpose(max_deg))
print(q.min(axis=0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP Spectre\OneDrive - student.kit.edu\uni\Master\Lissabon Kurse\Intelligent Systems\IntSysGroup6\Project\MLT_tuning\Data_exploration.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/HP%20Spectre/OneDrive%20-%20student.kit.edu/uni/Master/Lissabon%20Kurse/Intelligent%20Systems/IntSysGroup6/Project/MLT_tuning/Data_exploration.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> max_rad = q.max(axis=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP%20Spectre/OneDrive%20-%20student.kit.edu/uni/Master/Lissabon%20Kurse/Intelligent%20Systems/IntSysGroup6/Project/MLT_tuning/Data_exploration.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> max_deg = [math.degrees(angle) for angle in max_rad]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20Spectre/OneDrive%20-%20student.kit.edu/uni/Master/Lissabon%20Kurse/Intelligent%20Systems/IntSysGroup6/Project/MLT_tuning/Data_exploration.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> print(max_deg.t)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP%20Spectre/OneDrive%20-%20student.kit.edu/uni/Master/Lissabon%20Kurse/Intelligent%20Systems/IntSysGroup6/Project/MLT_tuning/Data_exploration.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> print(q.min(axis=0))
#
# AttributeError: 'list' object has no attribute 't'
